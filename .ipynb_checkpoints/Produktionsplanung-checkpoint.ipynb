# %%
# !pip install pulp;
# !pip install numpy;
# !pip install matplotlib;
# Out:
# Requirement already satisfied: pulp in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (3.3.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (2.4.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\elias\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pulp
import numpy as np
import matplotlib.pyplot as plt

# %%
# Profit: Geldeinheit pro Stück
pA, pB, pC = 30, 20, 40

# Fixkosten bei Produktion eines Produkts
fA, fB, fC = 400, 150, 50

# Matrix nb für Nebenbedingungen
nb = np.array([[2, 1, 3], [1, 2, 1], [1, 1, 2]])

# Zielvektor b
b = np.array([100, 90, 80])

# Hilfsvariable für yA, yB, yC
M = 1000

# %% [markdown]
# **Initialisierung von model**

# %%
model = pulp.LpProblem("Produktionsplanung", pulp.LpMaximize)

# %% [markdown]
# Produktionsmengen *xA, xB, xC* der Produkte *A, B, C*

# %%
xA = pulp.LpVariable("Prod_A", lowBound=0, cat="Integer")
xB = pulp.LpVariable("Prod_B", lowBound=0, cat="Integer")
xC = pulp.LpVariable("Prod_C", lowBound=0, cat="Integer")

yA = pulp.LpVariable("xA>0", cat="Binary")
yB = pulp.LpVariable("xB>0", cat="Binary")
yC = pulp.LpVariable("xC>0", cat="Binary")

# %% [markdown]
# **Zielfunktion**

# %%
model += pA*xA + pB*xB + pC*xC - fA*yA - fB*yB - fC*yC

# %% [markdown]
# **Nebenbedingungen:** Machinenkapazität, Materialmenge, Arbbeitszeit

# %%
for i, row in enumerate(nb):
    model += row[0]*xA + row[1]*xB + row[2]*xC <= b[i]

model += xA <= M*yA
model += xB <= M*yB
model += xC <= M*yC

# %% [markdown]
# **Lösen**

# %%
model.solve();
print("Status:", pulp.LpStatus[model.status])
print("A:", xA.value())
print("B:", xB.value())
print("C:", xC.value())
print("Max Profit:", pulp.value(model.objective))
# Out:
# Status: Optimal
# A: 0.0
# B: 34.0
# C: 22.0
# Max Profit: 1360.0

# %% [markdown]
# **Maschinenkapazität** (erste Zeile von nb) **variieren**

# %%
def solve_machine_capacity(mac_cap):
    model_cap = pulp.LpProblem("Produktionsplanung_cap", pulp.LpMaximize)

    xA = pulp.LpVariable("Prod_A", lowBound=0, cat="Integer")
    xB = pulp.LpVariable("Prod_B", lowBound=0, cat="Integer")
    xC = pulp.LpVariable("Prod_C", lowBound=0, cat="Integer")

    yA = pulp.LpVariable("xA>0", cat="Binary")
    yB = pulp.LpVariable("xB>0", cat="Binary")
    yC = pulp.LpVariable("xC>0", cat="Binary")

    model_cap += pA*xA + pB*xB + pC*xC - fA*yA - fB*yB - fC*yC

    b_test = b.copy()
    b_test[0] = mac_cap

    for i, row in enumerate(nb):
        model_cap += row[0]*xA + row[1]*xB + row[2]*xC <= b_test[i]
    
    model_cap += xA <= M*yA
    model_cap += xB <= M*yB
    model_cap += xC <= M*yC
    model_cap.solve()

    return pulp.value(model_cap.objective)

# %%
machine_caps = range(0, 101, 10)
profits = [solve_machine_capacity(i) for i in machine_caps]

print(list(zip(machine_caps, profits)))
# Out:
# [(0, 0.0), (10, 70.0), (20, 250.0), (30, 450.0), (40, 650.0), (50, 760.0), (60, 880.0), (70, 1000.0), (80, 1120.0), (90, 1240.0), (100, 1360.0)]

# %%
plt.plot(machine_caps, profits)
plt.xlabel("Machinenkapazität")
plt.ylabel("Max Profit")
plt.title("Profit in Abhängigkeit der Machinenkapazität")
plt.show()
